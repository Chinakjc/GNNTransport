# %%
from my_model import *
from my_data import *
from my_plot import *
from sklearn.metrics import explained_variance_score, r2_score
# Out:
# WARNING:tensorflow:From c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# 1. Set a global seed.
SEED = 1234  

# 2. OS Level: Guaranteeing that Python hashes are also reproducible  
os.environ['PYTHONHASHSEED'] = str(SEED)  

# 3. Make the underlying ops of TF use deterministic implementations as much as possible (2.x). 
os.environ['TF_DETERMINISTIC_OPS']    = '1'  
os.environ['TF_CUDNN_DETERMINISM']    = '1'  

# 4. Python comes with random built-in.
random.seed(SEED)  
# 5. NumPy  
np.random.seed(SEED)  
# 6. TensorFlow  
tf.random.set_seed(SEED)

# %%
#Read data
data = prepare_training_data("Berlin/berlin_extracted_train",
network_pattern_mid="network_berlin", ls_pattern_mid=".linkstats_berlin")  
data_val = prepare_training_data("Berlin/berlin_extracted_val",
network_pattern_mid="network_berlin", ls_pattern_mid=".linkstats_berlin")  

#Data Normalization
info = get_data_info(data)
data_nor =  min_max_nor_data(data,info)
data_val_nor = min_max_nor_data(data_val,info)
ds_nor = build_dataset(data_nor)
ds_val_nor = build_dataset(data_val_nor)
train_dataset_nor = ds_nor
batch_size = 32
train_ds_batched_nor = train_dataset_nor.shuffle(buffer_size=3,seed=SEED).batch(batch_size=batch_size).repeat()

# %%
model_input_graph_spec, label_spec = train_dataset_nor.element_spec
del label_spec  # Delete unused tag specifications

# Build model
model_nor = build_regression_model(
    graph_tensor_spec=model_input_graph_spec,
    node_dim=128,
    edge_dim=32,
    message_dim=128,
    next_state_dim=128,
    output_dim=25,  
    num_message_passing=3,
    l2_regularization=5e-5,
    dropout_rate=0.01, )

# Compile model
model_nor.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.MeanSquaredError(),
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# Print model structure
model_nor.summary()
# Out:
# WARNING:tensorflow:From c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tf_keras\src\engine\input_layer.py:200: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# WARNING:tensorflow:Mapping types may not work well with tf.nest. Prefer using MutableMapping for <class 'tensorflow_gnn.graph.graph_tensor._ImmutableMapping'>
# f =  KerasTensor(type_spec=TensorSpec(shape=(27664, 33), dtype=tf.float32, name=None), name='tf.concat/concat:0', description="created by layer 'tf.concat'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [()]                      0
#
#  input.merge_batch_to_compo  ()                        0
#  nents (InstanceMethod)
#
#  map_features (MapFeatures)  ()                        37440
#
#  graph_update (GraphUpdate)  ()                        65792
#
#  graph_update_1 (GraphUpdat  ()                        65792
#  e)
#
#  graph_update_2 (GraphUpdat  ()                        65792
#  e)
#
#  readout (Readout)           (27664, 128)              0
#
#  tf.expand_dims (TFOpLambda  (27664, 1, 128)           0
#  )
#
#  lambda (Lambda)             (1, 27664, 128)           0
#
#  dense_6 (Dense)             (1, 27664, 64)            8256
#
#  dense_7 (Dense)             (1, 27664, 64)            4160
#
#  dense_8 (Dense)             (1, 27664, 64)            4160
#
#  dense_9 (Dense)             (1, 27664, 25)            1625
#
# =================================================================
# Total params: 253017 (988.35 KB)
# Trainable params: 253017 (988.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train model
history_nor = model_nor.fit(train_ds_batched_nor, steps_per_epoch=10,epochs=150,validation_data=ds_val_nor)
# Out:
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:Gradients do not exist for variables ['dense_3/kernel:0', 'dense_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_3/kernel:0', 'dense_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_3/kernel:0', 'dense_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['dense_3/kernel:0', 'dense_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 10/10 [==============================] - 108s 10s/step - loss: 0.0508 - mean_absolute_error: 0.0235 - root_mean_squared_error: 0.0478 - val_loss: 0.0453 - val_mean_absolute_error: 0.0070 - val_root_mean_squared_error: 0.0191
# Epoch 2/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0424 - mean_absolute_error: 0.0070 - root_mean_squared_error: 0.0183 - val_loss: 0.0389 - val_mean_absolute_error: 0.0065 - val_root_mean_squared_error: 0.0174
# Epoch 3/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0363 - mean_absolute_error: 0.0063 - root_mean_squared_error: 0.0171 - val_loss: 0.0334 - val_mean_absolute_error: 0.0057 - val_root_mean_squared_error: 0.0168
# Epoch 4/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0312 - mean_absolute_error: 0.0056 - root_mean_squared_error: 0.0168 - val_loss: 0.0287 - val_mean_absolute_error: 0.0053 - val_root_mean_squared_error: 0.0167
# Epoch 5/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0269 - mean_absolute_error: 0.0053 - root_mean_squared_error: 0.0167 - val_loss: 0.0247 - val_mean_absolute_error: 0.0052 - val_root_mean_squared_error: 0.0166
# Epoch 6/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0232 - mean_absolute_error: 0.0053 - root_mean_squared_error: 0.0166 - val_loss: 0.0215 - val_mean_absolute_error: 0.0052 - val_root_mean_squared_error: 0.0166
# Epoch 7/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0202 - mean_absolute_error: 0.0053 - root_mean_squared_error: 0.0166 - val_loss: 0.0188 - val_mean_absolute_error: 0.0052 - val_root_mean_squared_error: 0.0165
# Epoch 8/150
# 10/10 [==============================] - 97s 10s/step - loss: 0.0178 - mean_absolute_error: 0.0053 - root_mean_squared_error: 0.0164 - val_loss: 0.0166 - val_mean_absolute_error: 0.0052 - val_root_mean_squared_error: 0.0162
# Epoch 9/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0158 - mean_absolute_error: 0.0054 - root_mean_squared_error: 0.0160 - val_loss: 0.0148 - val_mean_absolute_error: 0.0053 - val_root_mean_squared_error: 0.0155
# Epoch 10/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0141 - mean_absolute_error: 0.0056 - root_mean_squared_error: 0.0150 - val_loss: 0.0133 - val_mean_absolute_error: 0.0058 - val_root_mean_squared_error: 0.0138
# Epoch 11/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0127 - mean_absolute_error: 0.0057 - root_mean_squared_error: 0.0128 - val_loss: 0.0120 - val_mean_absolute_error: 0.0054 - val_root_mean_squared_error: 0.0112
# Epoch 12/150
# 10/10 [==============================] - 97s 10s/step - loss: 0.0115 - mean_absolute_error: 0.0049 - root_mean_squared_error: 0.0104 - val_loss: 0.0110 - val_mean_absolute_error: 0.0040 - val_root_mean_squared_error: 0.0089
# Epoch 13/150
# 10/10 [==============================] - 105s 11s/step - loss: 0.0106 - mean_absolute_error: 0.0038 - root_mean_squared_error: 0.0088 - val_loss: 0.0101 - val_mean_absolute_error: 0.0033 - val_root_mean_squared_error: 0.0078
# Epoch 14/150
# 10/10 [==============================] - 104s 10s/step - loss: 0.0098 - mean_absolute_error: 0.0031 - root_mean_squared_error: 0.0076 - val_loss: 0.0093 - val_mean_absolute_error: 0.0028 - val_root_mean_squared_error: 0.0069
# Epoch 15/150
# 10/10 [==============================] - 104s 10s/step - loss: 0.0091 - mean_absolute_error: 0.0028 - root_mean_squared_error: 0.0067 - val_loss: 0.0087 - val_mean_absolute_error: 0.0025 - val_root_mean_squared_error: 0.0060
# Epoch 16/150
# 10/10 [==============================] - 98s 10s/step - loss: 0.0085 - mean_absolute_error: 0.0026 - root_mean_squared_error: 0.0062 - val_loss: 0.0082 - val_mean_absolute_error: 0.0024 - val_root_mean_squared_error: 0.0056
# Epoch 17/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0080 - mean_absolute_error: 0.0025 - root_mean_squared_error: 0.0059 - val_loss: 0.0077 - val_mean_absolute_error: 0.0022 - val_root_mean_squared_error: 0.0054
# Epoch 18/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0075 - mean_absolute_error: 0.0024 - root_mean_squared_error: 0.0056 - val_loss: 0.0073 - val_mean_absolute_error: 0.0022 - val_root_mean_squared_error: 0.0051
# Epoch 19/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0071 - mean_absolute_error: 0.0023 - root_mean_squared_error: 0.0054 - val_loss: 0.0069 - val_mean_absolute_error: 0.0021 - val_root_mean_squared_error: 0.0050
# Epoch 20/150
# 10/10 [==============================] - 100s 10s/step - loss: 0.0067 - mean_absolute_error: 0.0022 - root_mean_squared_error: 0.0053 - val_loss: 0.0065 - val_mean_absolute_error: 0.0021 - val_root_mean_squared_error: 0.0049
# Epoch 21/150
# 10/10 [==============================] - 104s 10s/step - loss: 0.0064 - mean_absolute_error: 0.0022 - root_mean_squared_error: 0.0052 - val_loss: 0.0062 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0049
# Epoch 22/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0061 - mean_absolute_error: 0.0022 - root_mean_squared_error: 0.0053 - val_loss: 0.0059 - val_mean_absolute_error: 0.0021 - val_root_mean_squared_error: 0.0048
# Epoch 23/150
# 10/10 [==============================] - 104s 10s/step - loss: 0.0058 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0051 - val_loss: 0.0056 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0047
# Epoch 24/150
# 10/10 [==============================] - 100s 10s/step - loss: 0.0055 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0051 - val_loss: 0.0054 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0047
# Epoch 25/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0053 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0049
# Epoch 26/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0050 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0051 - val_loss: 0.0049 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0047
# Epoch 27/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0048 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0050 - val_loss: 0.0047 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0046
# Epoch 28/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0046 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0050 - val_loss: 0.0045 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0047
# Epoch 29/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0044 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0050 - val_loss: 0.0043 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0047
# Epoch 30/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0042 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0050 - val_loss: 0.0041 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 31/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0040 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0039 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0047
# Epoch 32/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0039 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0038 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 33/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0037 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0036 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 34/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0036 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0035 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0047
# Epoch 35/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0034 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0033 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0046
# Epoch 36/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0033 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0032 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 37/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0031 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 0.0031 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 38/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0030 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 0.0029 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 39/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0029 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 0.0028 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 40/150
# 10/10 [==============================] - 97s 10s/step - loss: 0.0028 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0047 - val_loss: 0.0027 - val_mean_absolute_error: 0.0022 - val_root_mean_squared_error: 0.0051
# Epoch 41/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0027 - mean_absolute_error: 0.0023 - root_mean_squared_error: 0.0056 - val_loss: 0.0027 - val_mean_absolute_error: 0.0027 - val_root_mean_squared_error: 0.0084
# Epoch 42/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0026 - mean_absolute_error: 0.0026 - root_mean_squared_error: 0.0069 - val_loss: 0.0025 - val_mean_absolute_error: 0.0023 - val_root_mean_squared_error: 0.0061
# Epoch 43/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0025 - mean_absolute_error: 0.0022 - root_mean_squared_error: 0.0056 - val_loss: 0.0024 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 44/150
# 10/10 [==============================] - 97s 10s/step - loss: 0.0024 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0049 - val_loss: 0.0023 - val_mean_absolute_error: 0.0021 - val_root_mean_squared_error: 0.0048
# Epoch 45/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0023 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 0.0022 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 46/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0022 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0022 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 47/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0021 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0021 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 48/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0020 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0020 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 49/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0020 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0019 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 50/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0019 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0019 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 51/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0018 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0018 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 52/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0018 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0017 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 53/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0017 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0047 - val_loss: 0.0017 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0051
# Epoch 54/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0016 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0047 - val_loss: 0.0016 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 55/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0016 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0015 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 56/150
# 10/10 [==============================] - 96s 10s/step - loss: 0.0015 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0015 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 57/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0015 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0014 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 58/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0014 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0014 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0046
# Epoch 59/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0014 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0013 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 60/150
# 10/10 [==============================] - 96s 9s/step - loss: 0.0013 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0013 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 61/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0013 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0012 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0046
# Epoch 62/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0012 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0012 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 63/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0012 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0047 - val_loss: 0.0012 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0049
# Epoch 64/150
# 10/10 [==============================] - 96s 9s/step - loss: 0.0011 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0011 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 65/150
# 10/10 [==============================] - 101s 10s/step - loss: 0.0011 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 0.0011 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 66/150
# 10/10 [==============================] - 103s 10s/step - loss: 0.0011 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0010 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0046
# Epoch 67/150
# 10/10 [==============================] - 102s 10s/step - loss: 0.0010 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 0.0010 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 68/150
# 10/10 [==============================] - 98s 10s/step - loss: 9.9392e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 9.7368e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0045
# Epoch 69/150
# 10/10 [==============================] - 102s 10s/step - loss: 9.6077e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 9.4079e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 70/150
# 10/10 [==============================] - 103s 10s/step - loss: 9.2813e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 9.0933e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 71/150
# 10/10 [==============================] - 106s 11s/step - loss: 8.9634e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 8.7804e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 72/150
# 10/10 [==============================] - 99s 10s/step - loss: 8.6553e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 8.5036e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 73/150
# 10/10 [==============================] - 103s 10s/step - loss: 8.3933e-04 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 8.2103e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 74/150
# 10/10 [==============================] - 105s 10s/step - loss: 8.0907e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 7.9212e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 75/150
# 10/10 [==============================] - 104s 10s/step - loss: 7.8245e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 7.6689e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 76/150
# 10/10 [==============================] - 97s 10s/step - loss: 7.5672e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 7.4474e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0049
# Epoch 77/150
# 10/10 [==============================] - 104s 10s/step - loss: 7.3230e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 7.1583e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 78/150
# 10/10 [==============================] - 104s 10s/step - loss: 7.0736e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 6.9195e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 79/150
# 10/10 [==============================] - 102s 10s/step - loss: 6.8359e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 6.7049e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0045
# Epoch 80/150
# 10/10 [==============================] - 97s 10s/step - loss: 6.6253e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 6.4974e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 81/150
# 10/10 [==============================] - 102s 10s/step - loss: 6.4084e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 6.2931e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0047
# Epoch 82/150
# 10/10 [==============================] - 101s 10s/step - loss: 6.1979e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 6.0681e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 83/150
# 10/10 [==============================] - 102s 10s/step - loss: 5.9922e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 5.8654e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 84/150
# 10/10 [==============================] - 96s 10s/step - loss: 5.7952e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 5.6809e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0045
# Epoch 85/150
# 10/10 [==============================] - 101s 10s/step - loss: 5.6273e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0048 - val_loss: 5.5042e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 86/150
# 10/10 [==============================] - 101s 10s/step - loss: 5.4255e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 5.3076e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 87/150
# 10/10 [==============================] - 101s 10s/step - loss: 5.2582e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 5.1519e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0045
# Epoch 88/150
# 10/10 [==============================] - 96s 9s/step - loss: 5.0932e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 4.9753e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 89/150
# 10/10 [==============================] - 101s 10s/step - loss: 4.9340e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 4.8480e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0047
# Epoch 90/150
# 10/10 [==============================] - 102s 10s/step - loss: 4.7666e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 4.6679e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 91/150
# 10/10 [==============================] - 102s 10s/step - loss: 4.6112e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 4.5307e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 92/150
# 10/10 [==============================] - 96s 10s/step - loss: 4.4777e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 4.4194e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0049
# Epoch 93/150
# 10/10 [==============================] - 102s 10s/step - loss: 4.3377e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 4.2312e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 94/150
# 10/10 [==============================] - 101s 10s/step - loss: 4.1922e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 4.0985e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 95/150
# 10/10 [==============================] - 101s 10s/step - loss: 4.0656e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 4.0132e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0048
# Epoch 96/150
# 10/10 [==============================] - 95s 9s/step - loss: 3.9410e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 3.8460e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 97/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.8142e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 3.7391e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0045
# Epoch 98/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.6994e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 3.6111e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 99/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.5836e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 3.5141e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0045
# Epoch 100/150
# 10/10 [==============================] - 96s 10s/step - loss: 3.4668e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 3.3983e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 101/150
# 10/10 [==============================] - 102s 10s/step - loss: 3.3622e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 3.3299e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0048
# Epoch 102/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.2672e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 3.2085e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 103/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.1686e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0047 - val_loss: 3.0868e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 104/150
# 10/10 [==============================] - 97s 10s/step - loss: 3.0596e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 3.0006e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 105/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.9724e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0046 - val_loss: 2.8979e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 106/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.8803e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 2.8890e-04 - val_mean_absolute_error: 0.0023 - val_root_mean_squared_error: 0.0051
# Epoch 107/150
# 10/10 [==============================] - 101s 10s/step - loss: 3.1287e-04 - mean_absolute_error: 0.0026 - root_mean_squared_error: 0.0073 - val_loss: 4.1978e-04 - val_mean_absolute_error: 0.0046 - val_root_mean_squared_error: 0.0128
# Epoch 108/150
# 10/10 [==============================] - 97s 10s/step - loss: 3.3325e-04 - mean_absolute_error: 0.0033 - root_mean_squared_error: 0.0090 - val_loss: 2.8117e-04 - val_mean_absolute_error: 0.0025 - val_root_mean_squared_error: 0.0056
# Epoch 109/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.8019e-04 - mean_absolute_error: 0.0024 - root_mean_squared_error: 0.0058 - val_loss: 2.6836e-04 - val_mean_absolute_error: 0.0023 - val_root_mean_squared_error: 0.0051
# Epoch 110/150
# 10/10 [==============================] - 102s 10s/step - loss: 2.6312e-04 - mean_absolute_error: 0.0022 - root_mean_squared_error: 0.0049 - val_loss: 2.5725e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0048
# Epoch 111/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.5219e-04 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0046 - val_loss: 2.4628e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 112/150
# 10/10 [==============================] - 97s 10s/step - loss: 2.4329e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 2.3733e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 113/150
# 10/10 [==============================] - 102s 10s/step - loss: 2.3519e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 2.2970e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 114/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.2762e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 2.2247e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 115/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.2050e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 2.1566e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 116/150
# 10/10 [==============================] - 96s 10s/step - loss: 2.1393e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 2.0912e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 117/150
# 10/10 [==============================] - 102s 10s/step - loss: 2.0754e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 2.0285e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 118/150
# 10/10 [==============================] - 101s 10s/step - loss: 2.0131e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.9685e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 119/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.9531e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 120/150
# 10/10 [==============================] - 96s 10s/step - loss: 1.8971e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.8546e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 121/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.8422e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.8006e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 122/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.7884e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.7485e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 123/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.7359e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.6982e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 124/150
# 10/10 [==============================] - 96s 10s/step - loss: 1.6873e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.6493e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 125/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.6393e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.6033e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 126/150
# 10/10 [==============================] - 103s 10s/step - loss: 1.5929e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.5567e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 127/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.5467e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.5122e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 128/150
# 10/10 [==============================] - 97s 10s/step - loss: 1.5037e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.4696e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 129/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.4617e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.4284e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 130/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.4257e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0045 - val_loss: 1.3906e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 131/150
# 10/10 [==============================] - 100s 10s/step - loss: 1.3824e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.3502e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 132/150
# 10/10 [==============================] - 95s 9s/step - loss: 1.3452e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.3129e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 133/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.3073e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.2796e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 134/150
# 10/10 [==============================] - 100s 10s/step - loss: 1.2803e-04 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 1.2456e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 135/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.2446e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0045 - val_loss: 1.2185e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 136/150
# 10/10 [==============================] - 96s 10s/step - loss: 1.2092e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.1800e-04 - val_mean_absolute_error: 0.0017 - val_root_mean_squared_error: 0.0043
# Epoch 137/150
# 10/10 [==============================] - 102s 10s/step - loss: 1.1754e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.1539e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0044
# Epoch 138/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.1465e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.1145e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 139/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.1138e-04 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 1.1337e-04 - val_mean_absolute_error: 0.0019 - val_root_mean_squared_error: 0.0048
# Epoch 140/150
# 10/10 [==============================] - 96s 10s/step - loss: 1.1216e-04 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0048 - val_loss: 1.0636e-04 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 141/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.2612e-04 - mean_absolute_error: 0.0023 - root_mean_squared_error: 0.0063 - val_loss: 1.1032e-04 - val_mean_absolute_error: 0.0022 - val_root_mean_squared_error: 0.0050
# Epoch 142/150
# 10/10 [==============================] - 101s 10s/step - loss: 1.2286e-04 - mean_absolute_error: 0.0025 - root_mean_squared_error: 0.0062 - val_loss: 1.1935e-04 - val_mean_absolute_error: 0.0025 - val_root_mean_squared_error: 0.0059
# Epoch 143/150
# 10/10 [==============================] - 103s 10s/step - loss: 1.0889e-04 - mean_absolute_error: 0.0021 - root_mean_squared_error: 0.0051 - val_loss: 1.0329e-04 - val_mean_absolute_error: 0.0020 - val_root_mean_squared_error: 0.0046
# Epoch 144/150
# 10/10 [==============================] - 96s 9s/step - loss: 1.0226e-04 - mean_absolute_error: 0.0020 - root_mean_squared_error: 0.0047 - val_loss: 9.7983e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0044
# Epoch 145/150
# 10/10 [==============================] - 102s 10s/step - loss: 9.7992e-05 - mean_absolute_error: 0.0019 - root_mean_squared_error: 0.0045 - val_loss: 9.5199e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 146/150
# 10/10 [==============================] - 102s 10s/step - loss: 9.4774e-05 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 9.2243e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 147/150
# 10/10 [==============================] - 101s 10s/step - loss: 9.1927e-05 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 8.9533e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 148/150
# 10/10 [==============================] - 96s 10s/step - loss: 8.9456e-05 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 8.7040e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 149/150
# 10/10 [==============================] - 101s 10s/step - loss: 8.7119e-05 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 8.4799e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043
# Epoch 150/150
# 10/10 [==============================] - 101s 10s/step - loss: 8.4880e-05 - mean_absolute_error: 0.0018 - root_mean_squared_error: 0.0044 - val_loss: 8.2643e-05 - val_mean_absolute_error: 0.0018 - val_root_mean_squared_error: 0.0043

# %%
#Save model
tf.saved_model.save(model_nor, "Berlin/my_saved_model_berlin") 

with open("Berlin/train_history_berlin.json", "w") as f:  
    json.dump(history_nor.history, f)
# Out:
# c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tensorflow\python\saved_model\nested_structure_coder.py:458: UserWarning: Encoding a StructuredValue with type tensorflow_gnn.GraphTensorSpec; loading this StructuredValue will require that this type be imported and registered.
#   warnings.warn("Encoding a StructuredValue with type %s; loading this "
# c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tensorflow\python\saved_model\nested_structure_coder.py:458: UserWarning: Encoding a StructuredValue with type tensorflow_gnn.ContextSpec.v2; loading this StructuredValue will require that this type be imported and registered.
#   warnings.warn("Encoding a StructuredValue with type %s; loading this "
# c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tensorflow\python\saved_model\nested_structure_coder.py:458: UserWarning: Encoding a StructuredValue with type tensorflow_gnn.NodeSetSpec; loading this StructuredValue will require that this type be imported and registered.
#   warnings.warn("Encoding a StructuredValue with type %s; loading this "
# c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tensorflow\python\saved_model\nested_structure_coder.py:458: UserWarning: Encoding a StructuredValue with type tensorflow_gnn.EdgeSetSpec; loading this StructuredValue will require that this type be imported and registered.
#   warnings.warn("Encoding a StructuredValue with type %s; loading this "
# c:\Users\ke\AppData\Local\anaconda3\envs\tfgnn\lib\site-packages\tensorflow\python\saved_model\nested_structure_coder.py:458: UserWarning: Encoding a StructuredValue with type tensorflow_gnn.AdjacencySpec; loading this StructuredValue will require that this type be imported and registered.
#   warnings.warn("Encoding a StructuredValue with type %s; loading this "
# INFO:tensorflow:Assets written to: Berlin/my_saved_model_berlin\assets
# INFO:tensorflow:Assets written to: Berlin/my_saved_model_berlin\assets

# %%
history_plot = history_nor
metrics = [m for m in history_plot.history if not m.startswith("val_")]  
n = len(metrics)  

fig, axes = plt.subplots(n, 1, figsize=(8, 4 * n), squeeze=False)  
for i, metric in enumerate(metrics):  
    val_metric = f"val_{metric}"  
    if val_metric not in history_plot.history:  
        continue  

    epochs = range(1, len(history_plot.history[metric]) + 1)  
    ax1 = axes[i, 0]  
    ax2 = ax1.twinx()  

    # train  
    ax1.plot(epochs, history_plot.history[metric],  
             color='blue',  label=f"train {metric}")  
    ax1.set_ylabel(f"train {metric}", color='blue')  
    ax1.tick_params(axis='y', colors='blue')  

    # val  
    ax2.plot(epochs, history_plot.history[val_metric],  
             color='orange',  label=f"val {metric}",linestyle="--")  
    ax2.set_ylabel(f"val {metric}", color='orange')  
    ax2.tick_params(axis='y', colors='orange')  

     
    ax1.set_xlabel("Epoch")  
    ax1.grid(True, linestyle="--", alpha=0.5)  
    lines = ax1.get_lines() + ax2.get_lines()  
    labels = [l.get_label() for l in lines]  
    ax1.legend(lines, labels, loc="best")  
    ax1.set_title(f"{metric} Train vs Validation")  

plt.tight_layout()  
plt.show()
